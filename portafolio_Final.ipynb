# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeca07-pedrozo/Python_ciencia_de_datos/blob/main/portafolio_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.colab.drive
google.colab.drive.mount('/content/drive')

file_path = '/content/drive/My Drive/Online_Retail.csv'

import pandas as pd
datos = pd.read_csv(file_path, encoding='latin1')

print(datos.head())
# Out:
# Mounted at /content/drive
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
print(datos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# None

# %%
print(datos.head(5))
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
print(datos.describe())
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
datos.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
datos.duplicated().sum()
# Out:
# np.int64(5268)

# %%
unique_values = {col: datos[col].unique() for col in datos.columns}
for col, values in unique_values.items():
  print (f'{col}: {values}')
  print(f'Numero de valores unicos : {len(values)}')
  print(f'Valores unicos:{values[:10,]}')
  print('-')
# Out:
# InvoiceNo: ['536365' '536366' '536367' ... '581585' '581586' '581587']
# Numero de valores unicos : 25900
# Valores unicos:['536365' '536366' '536367' '536368' '536369' '536370' '536371' '536372'
#  '536373' '536374']
# -
# StockCode: ['85123A' '71053' '84406B' ... '90214U' '47591b' '23843']
# Numero de valores unicos : 4070
# Valores unicos:['85123A' '71053' '84406B' '84029G' '84029E' '22752' '21730' '22633'
#  '22632' '84879']
# -
# Description: ['WHITE HANGING HEART T-LIGHT HOLDER' 'WHITE METAL LANTERN'
#  'CREAM CUPID HEARTS COAT HANGER' ... 'lost'
#  'CREAM HANGING HEART T-LIGHT HOLDER' 'PAPER CRAFT , LITTLE BIRDIE']
# Numero de valores unicos : 4224
# Valores unicos:['WHITE HANGING HEART T-LIGHT HOLDER' 'WHITE METAL LANTERN'
#  'CREAM CUPID HEARTS COAT HANGER' 'KNITTED UNION FLAG HOT WATER BOTTLE'
#  'RED WOOLLY HOTTIE WHITE HEART.' 'SET 7 BABUSHKA NESTING BOXES'
#  'GLASS STAR FROSTED T-LIGHT HOLDER' 'HAND WARMER UNION JACK'
# ...

# %%
data_frame=datos.drop_duplicates()
data_cleaned=data_frame.dropna(subset=['CustomerID'])
print(data_cleaned.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
print(datos.isnull().sum())
print('-')
print(data_cleaned.isnull().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
# -
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
data_cleaned.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
data_cleaned['TotalAmount'] = data_cleaned['Quantity']*data_cleaned['UnitPrice']
data_cleaned.head()
# Out:
# /tmp/ipython-input-11-3639529571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['TotalAmount'] = data_cleaned['Quantity']*data_cleaned['UnitPrice']
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom        15.30
# ...

# %%
data_cleaned['InvoiceDate']=pd.to_datetime(data_cleaned['InvoiceDate'])
data_cleaned.head()
# Out:
# /tmp/ipython-input-12-3556201911.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data_cleaned['InvoiceDate']=pd.to_datetime(data_cleaned['InvoiceDate'])
# /tmp/ipython-input-12-3556201911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['InvoiceDate']=pd.to_datetime(data_cleaned['InvoiceDate'])
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# ...

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 401604 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
#  8   TotalAmount  401604 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 30.6+ MB

# %%
data_cleaned['Year']=data_cleaned['InvoiceDate'].dt.year
data_cleaned['Month']=data_cleaned['InvoiceDate'].dt.month
print(data_cleaned.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
#
#    Year  Month
# 0  2010     12
# 1  2010     12
# 2  2010     12
# 3  2010     12
# 4  2010     12
# ...

# %%
sales_by_year=data_cleaned.groupby('Year')['TotalAmount'].sum()
sales_by_year
# Out:
# Year
# 2010     552372.860
# 2011    7726146.564
# Name: TotalAmount, dtype: float64

# %%
data_cleaned['Semester']=data_cleaned['Month'].apply(lambda x:1 if x<=6 else 2)
# Out:
# /tmp/ipython-input-19-2397660546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Semester']=data_cleaned['Month'].apply(lambda x:1 if x<=6 else 2)

# %%
data_cleaned['Trimester'] = data_cleaned['Month'].apply(lambda x: 1 if x <= 3 else (2 if x <= 6 else (3 if x <= 9 else 4)))
# Out:
# /tmp/ipython-input-23-3403088624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Trimester'] = data_cleaned['Month'].apply(lambda x: 1 if x <= 3 else (2 if x <= 6 else (3 if x <= 9 else 4)))

# %%
sales_by_semester=data_cleaned.groupby(['Year', 'Semester'])['TotalAmount'].sum()
print(sales_by_semester)
# Out:
# Year  Semester
# 2010  2            552372.860
# 2011  1           3166939.041
#       2           4559207.523
# Name: TotalAmount, dtype: float64

# %%
sales_by_trimester=data_cleaned.groupby(['Year', 'Trimester'])['TotalAmount'].sum()
print(sales_by_trimester)
# Out:
# Year  Trimester
# 2010  4             552372.860
# 2011  1            1487842.180
#       2            1679096.861
#       3            2117546.643
#       4            2441660.880
# Name: TotalAmount, dtype: float64

# %%
data_cleaned.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
#
#    Year  Month  Semester  Trimester
# 0  2010     12         2          4
# ...

# %%
total_returns=data_cleaned[data_cleaned['Quantity'] <0 ].shape[0]
total_returns
# Out:
# 8872

# %%
total_non_returns=data_cleaned[data_cleaned['Quantity'] >=0 ].shape[0]
total_non_returns
# Out:
# 392732

# %%
import matplotlib.pyplot as plt
labels= ['Devoluciones', 'No Devoluciones']
sizes = [total_returns,total_non_returns]
colors = [ 'lightcoral','lightgreen' ]
plt.figure(figsize=(8,8))
plt.pie(sizes, labels=labels,colors=colors  , startangle=140)
plt.title('Porcentaje de transacciones con y sin devoluciones')
plt.show()

# %%
def categorize_total_amount(amount):
  if amount < 20:
    return 'Bajo'
  elif amount < 100:
    return 'Medio'
  else:
    return 'Alto'
data_cleaned['AmountCategory']=data_cleaned['TotalAmount'].apply(categorize_total_amount)
print(data_cleaned.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
#
#    Year  Month  Semester  Trimester AmountCategory
# 0  2010     12         2          4           Bajo
# ...

# %%
category_counts = data_cleaned['AmountCategory'].value_counts()
labels = category_counts.index
sizes = category_counts.values
colors = ['lightgreen', 'lightcoral', 'skyblue']
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, startangle=140, autopct='%1.1f%%')
plt.title('Categorización de TotalAmount')
plt.show()

# %%
plt.figure(figsize=(12, 6))
data_cleaned.groupby(['Year', 'Month'])['TotalAmount'].sum().plot(kind='bar')
plt.title('Distribucion de ventas por mes y year')
plt.xlabel('Year, Month')
plt.ylabel('Total de ventas')
plt.show()

# %%
data_cleaned.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'TotalAmount', 'Year', 'Month',
#        'Semester', 'Trimester', 'AmountCategory'],
#       dtype='object')

# %%
top_products=data_cleaned.groupby('StockCode')['Quantity'].sum().sort_values(ascending=False).head(10)
top_products = top_products.reset_index()
top_products=pd.merge(top_products, data_cleaned[['StockCode', 'Description']].drop_duplicates(),
                        on='StockCode', how=' left')

# %%
plt.figure(figsize=(12,8))
plt.barh(top_products['Description'],top_products['Quantity'])
plt.title('Top de productos')
plt.xlabel('Cantidad vendida')
plt.ylabel('Cantidad de productos')
plt.gca().invert_yaxis()
plt.show()
